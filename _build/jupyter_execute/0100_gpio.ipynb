# %% [markdown]
# # GPIO
#
# ```{toctree}
# :titlesonly: True
# :caption: Vlastnosti a programovanie
# 0101_gpio_basic.md
# 0102_gpio_pyb.md
# ```
#
# ```{toctree}
# :titlesonly: True
# :caption: Periférie
# 0105_gpio_onboard.md
# ```
