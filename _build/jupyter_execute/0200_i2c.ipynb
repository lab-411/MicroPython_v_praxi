# %% [markdown]
# # I2C
#
# ```{toctree}
# :titlesonly: True
# :caption: Vlastnosti a programovanie
# 0201_i2c_basic.md
# 0202_i2c_pyb.md
# ```
#
# ```{toctree}
# :titlesonly: True
# :caption: Periférie
# 0205_i2c_lm92.md
# 0207_i2c_display.md
# 0209_i2c_mems.md
# ```
