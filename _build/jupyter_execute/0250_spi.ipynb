# %% [markdown]
# #  SPI
#
# ```{toctree}
# :titlesonly: True
# :caption: Vlastnosti a programovanie
# 0251_spi_basic.md
# 0252_spi_pyb.md
# ```
#
# ```{toctree}
# :titlesonly: True
# :caption: Periférie
# 0255_spi_display_7219.md
# 0257_spi_display_12864.md
# ```
